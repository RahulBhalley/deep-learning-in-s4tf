// %% [markdown]
// <a href="https://colab.research.google.com/github/rahulbhalley/swift-for-tensorflow-examples/blob/master/NeuralNetworks/WassersteinGAN/WassersteinGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

// %% [markdown]
// ## Import dependencies

// %%
import TensorFlow
import Python
PythonLibrary.useVersion(3)

let plt = Python.import("matplotlib.pyplot")
let time = Python.import("time")

// %% [markdown]
// ## Data Downloading and Loading Helpers

// %%
func downloadCIFAR10IfNotPresent(to directory: String = ".") {
  let subprocess = Python.import("subprocess")
  let path = Python.import("os.path")
  let filepath = "\(directory)/cifar-10-batches-py"
  let isdir = Bool(path.isdir(filepath))!
  if !isdir {
    print("Downloading CIFAR data...")
    let command = "wget -nv -O- https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz | tar xzf - -C \(directory)"
    subprocess.call(command, shell: true)
  }
}

struct Example: TensorGroup {
  var label: Tensor<Int32>
  var data: Tensor<Float>
}

// Each CIFAR data file is provided as a Python pickle of NumPy arrays
func loadCIFARFile(named name: String, in directory: String = ".") -> Example {
  downloadCIFAR10IfNotPresent(to: directory)
  let np = Python.import("numpy")
  let pickle = Python.import("pickle")
  let path = "\(directory)/cifar-10-batches-py/\(name)"
  let f = Python.open(path, "rb")
  let res = pickle.load(f, encoding: "bytes")

  let bytes = res[Python.bytes("data", encoding: "utf8")]
  let labels = res[Python.bytes("labels", encoding: "utf8")]

  let labelTensor = Tensor<Int64>(numpy: np.array(labels))!
  let images = Tensor<UInt8>(numpy: bytes)!
  let imageCount = images.shape[0]

  // reshape and transpose from the provided N(CHW) to TF default NHWC
  let imageTensor = Tensor<Float>(images
      .reshaped(to: [imageCount, 3, 32, 32])
      .transposed(withPermutations: [0, 2, 3, 1]))

  let mean = Tensor<Float>([0.485, 0.456, 0.406])
  let std  = Tensor<Float>([0.229, 0.224, 0.225])
  let imagesNormalized = ((imageTensor / 255.0) - mean) / std

  return Example(label: Tensor<Int32>(labelTensor), data: imagesNormalized)
}

func loadCIFARTrainingFiles() -> Example {
  let data = (1..<6).map { loadCIFARFile(named: "data_batch_\($0)") }
  return Example(
    label: Raw.concat(concatDim: Tensor<Int32>(0), data.map { $0.label }),
    data: Raw.concat(concatDim: Tensor<Int32>(0), data.map { $0.data })
  )
}

func loadCIFARTestFile() -> Example {
  return loadCIFARFile(named: "test_batch")
}

func loadCIFAR10() -> (
  training: Dataset<Example>, test: Dataset<Example>) {
    let trainingDataset = Dataset<Example>(elements: loadCIFARTrainingFiles())
    let testDataset = Dataset<Example>(elements: loadCIFARTestFile())
    return (training: trainingDataset, test: testDataset)
}

// %% [markdown]
// ## Extra functions
// - LeakyReLU

// %%
@differentiable
func leakyReLU(_ tensor: Tensor<Float>, negativeSlope: Float) -> Tensor<Float> {
  let zeros = Tensor<Float>(zeros: tensor.shape)
  let minimum = min(zeros, tensor)
  let maximum = max(zeros, tensor)
  let output = maximum + negativeSlope * minimum
  return output
}
/*
func clamp<Parameter: BinaryFloatingPoint, Parameters: KeyPathIterable>(_ parameters: inout Parameters, 
                                                                        low: Parameter = -0.01, 
                                                                        high: Parameter = 0.01) {
  // Iterate over recursively all writable key paths to the
  // parameter type.
  for kp in parameters.recursivelyAllWritableKeyPaths(to: Parameter.self) {
    // Define some new Tensors
//     let lowTensor = Tensor<Float>(repeating: low, shape: parameters[keyPath: kp].shape)
//     let highTensor = Tensor<Float>(repeating: high, shape: parameters[keyPath: kp].shape)
    print(parameters[keyPath: kp])
    if parameters[keyPath: kp] < low {
      parameters[keyPath: kp] = low
    } else if parameters[keyPath: kp] > high {
      parameters[keyPath: kp] = high
    }
//     print(parameters[keyPath: kp])
    print("Yeah!")
  }
//   print("Yeah!")
}
*/

// %% [markdown]
// ## Configurations

// %%
let batchSize = 64
let imageSize = 64
let numberOfChannels = 3
let zLatent = 128
let numberOfEpochs = 5

let lowClampValue: Float = -0.01
let highClampValue: Float = 0.01

// %% [markdown]
// ## Model

// %% [markdown]
// ### Helper Layers
// - ConvBN
// - TransposedConvBN
// - UpSampleConvBN

// %%
struct ConvBN: Layer, KeyPathIterable {
  typealias Input = Tensor<Float>
  typealias Output = Tensor<Float>

  var conv: Conv2D<Float>
  var norm: BatchNorm<Float>

  init(
    filterShape: (Int, Int, Int, Int),
    strides: (Int, Int) = (1, 1),
    padding: Padding = .valid
  ) {
    self.conv = Conv2D(filterShape: filterShape, strides: strides, padding: padding)
    self.norm = BatchNorm(featureCount: filterShape.3)
  }

  @differentiable
  func call(_ input: Input) -> Output {
    return input.sequenced(through: conv, norm)
  }
}

// DOES NOT WORK
// Currently, TransposedConv2D requires same number of input & output channels. FACK! 😒
struct TransposedConvBN: Layer, KeyPathIterable {
  typealias Input = Tensor<Float>
  typealias Output = Tensor<Float>

  var conv: TransposedConv2D
  var norm: BatchNorm<Float>

  init(
    filterShape: (Int, Int, Int, Int),
    strides: (Int, Int) = (1, 1),
    padding: Padding = .valid
  ) {
    self.conv = TransposedConv2D(filterShape: filterShape, strides: strides, padding: padding)
    self.norm = BatchNorm(featureCount: filterShape.3)
  }

  @differentiable
  func call(_ input: Input) -> Output {
    return input.sequenced(through: conv, norm)
  }
}

struct UpSampleConvBN: Layer, KeyPathIterable {
  typealias Input = Tensor<Float>
  typealias Output = Tensor<Float>
  
  var upSample: UpSampling2D<Float>
  var conv: Conv2D<Float>
  var norm: BatchNorm<Float>
  
  init(
    filterShape: (Int, Int, Int, Int),
    strides: (Int, Int),
    padding: Padding = .same
  ) {
    self.upSample = UpSampling2D(size: 4)
    self.conv = Conv2D(filterShape: filterShape, strides: strides, padding: padding)
    self.norm = BatchNorm(featureCount: filterShape.3)
  }
  
  @differentiable
  func call(_ input: Input) -> Output {
    return input.sequenced(through: upSample, conv, norm)
  }
}

// %% [markdown]
// ### Generative Adversarial Network
// - Generator
// - Critic

// %%
struct Generator: Layer, KeyPathIterable {
  typealias Input = Tensor<Float>
  typealias Output = Tensor<Float>
  
  var dense = Dense<Float>(inputSize: zLatent, outputSize: 2 * 2 * 1024)
  var norm = BatchNorm<Float>(featureCount: 4096)
  var upSampleConvBN1 = UpSampleConvBN(
    filterShape: (4, 4, 512, 256),
    strides: (2, 2),
    padding: .same
  )
  var upSampleConvBN2 = UpSampleConvBN(
    filterShape: (4, 4, 256, 128),
    strides: (2, 2),
    padding: .same
  )
  var upSampleConvBN3 = UpSampleConvBN(
    filterShape: (4, 4, 128, 64),
    strides: (2, 2),
    padding: .same
  )
//   var upSampleConvBN4 = UpSampleConvBN(
//     filterShape: (4, 4, 128, 64),
//     strides: (2, 2),
//     padding: .same
//   )
  var upSample = UpSampling2D<Float>(size: 4)
  var conv = Conv2D<Float>(
    filterShape: (4, 4, 64, numberOfChannels), 
    strides: (2, 2), 
    padding: .same
  )
  
  @differentiable
  func call(_ input: Input) -> Output {
    var output: Output
    // Dense activation
    output = relu(norm(dense(input)))
    // Expand shape to 4D
    output = output.expandingShape(at: 0).expandingShape(at: 0)
    // Reshape and transpose from N(CHW) to N(HWC)
//     print(output.shape)
    output = output.reshaped(to: [batchSize, 1024, 2, 2]) // N(CHW)
    output = output.transposed(withPermutations: [0, 2, 3, 1]) // NHWC
    // Upsample and convolve through remaining layers
    // 🧻: (Distill: Deconvolution and Checkerboard Artifacts)
    output = relu(upSampleConvBN1(output))
    output = relu(upSampleConvBN2(output))
    output = relu(upSampleConvBN3(output))
//     output = relu(upSampleConvBN4(output))
    output = tanh(conv(upSample(output)))
    return output
  }
}

struct Critic: Layer, KeyPathIterable {
  typealias Input = Tensor<Float>
  typealias Output = Tensor<Float>
  
  var convBN1 = Conv2D<Float>(
    filterShape: (4, 4, numberOfChannels, 64),
    strides: (2, 2),
    padding: .same
  )
  var convBN2 = ConvBN(
    filterShape: (4, 4, 64, 128),
    strides: (2, 2),
    padding: .same
  )
  var convBN3 = ConvBN(
    filterShape: (4, 4, 128, 256),
    strides: (2, 2),
    padding: .same
  )
  var convBN4 = ConvBN(
    filterShape: (4, 4, 256, 512),
    strides: (2, 2),
    padding: .same
  )
//   var convBN5 = ConvBN(
//     filterShape: (4, 4, 512, 1024),
//     strides: (2, 2),
//     padding: .same
//   )
  var flatten = Flatten<Float>()
  var dense = Dense<Float>(inputSize: 2 * 2 * 512, outputSize: 1)
  
  @differentiable
  func call(_ input: Input) -> Output {
    var output: Output
    output = leakyReLU(convBN1(input),  negativeSlope: 0.2)
    output = leakyReLU(convBN2(output), negativeSlope: 0.2)
    output = leakyReLU(convBN3(output), negativeSlope: 0.2)
    output = leakyReLU(convBN4(output), negativeSlope: 0.2)
//     output = leakyReLU(convBN5(output), negativeSlope: 0.2)
    output = flatten(output)
    output = dense(output)
    return output
  }
}

// %% [markdown]
// ## Set up dataset, inputs, models, and optimizers

// %% [markdown]
// - Dataset

// %%
// Load the dataset
let cifarDataset = loadCIFAR10()
let testBatches = cifarDataset.test.batched(batchSize)

// %% [markdown]
// - Input
// - Generative Adversarial Nets
// - Optimizers

// %%
// Inputs
var zInput = Tensor<Float>(randomUniform: [batchSize, zLatent])
// var zInput: Tensor<Float>

// Iterations for Critic
let numberOfCriticIterations = 1

// Models
var generatorModel = Generator()
var criticModel = Critic()

// Optimizers
// let generatorOptimizer = Adam(for: generatorModel, learningRate: 0.0002, beta2: 0.5)
// let criticOptimizer = Adam(for: criticModel, learningRate: 0.0002, beta2: 0.5)
let generatorOptimizer = RMSProp(for: generatorModel, learningRate: 5e-5)
let criticOptimizer = RMSProp(for: criticModel, learningRate: 5e-5)

// %%
// var input = Tensor<Float>(glorotUniform: [batchSize, imageSize, imageSize, numberOfChannels])
// var input = Tensor<Float>(glorotUniform: [batchSize, zLatent])
// print("input: \(input.shape)")

// var outputGenerator = generatorModel(input)
// print("generator: \(outputGenerator.shape)")

// var outputCritic = criticModel(outputGenerator)
// print("outputCritic: \(outputCritic.shape)")

// criticModel.allDifferentiableVariables = criticModel.allDifferentiableVariables.withoutDerivative()

// %%
print(Context.local.learningPhase)
Context.local.learningPhase = .training
print(Context.local.learningPhase)
// Out:
// inference
// training

// %% [markdown]
// ## Training

// %%
// Store arrays of all the losses
var wassersteinDistances = [Float]()
var criticLosses = [Float]()
var generatorLosses = [Float]()

// Begin training.
print("Started. 🛫")

// Setup the training context
Context.local.learningPhase = .training

for epoch in 1...numberOfEpochs {
  var startTime = time.time()

  //var trainingLossSum: Float = 0
  var trainingBatchCount = 0

  // Shuffle the dataset
  let trainingShuffled = cifarDataset.training.shuffled(
      sampleCount: 50000,
      randomSeed: Int64(epoch)
  )

  // Start the training now
  for (iteration, batch) in trainingShuffled.batched(batchSize).enumerated() {
    //let (_, images) = (batch.label, batch.data)
    let images = batch.data

    if images.shape[0] != batchSize {
      print("Shapes not compatible: \(images.shape) != [\(batchSize), 1]. Skipping")
      continue
    }

    // Track Wasserstein distance
    var wassersteinDistance: Float = 0

    /*
     Train `criticModel` one step
     */
    var averageCriticLoss: Float = 0

    for _ in 1...numberOfCriticIterations {
      let (criticLoss, criticGradients) = valueWithGradient(at: criticModel) {
        criticModel -> Tensor<Float> in

        // Sample uniformly from normal distribution of [`batchSize`, `zLatent`] shaped `Tensor`
        zInput = Tensor<Float>(randomUniform: [batchSize, zLatent])
        //print(zInput.shape)

        // Forward pass `zInput` through `generatorModel`
        // and don't track gradients of `generatorModel`.
        let Gz = generatorModel(zInput).withoutDerivative()
        //print(generatedImage.shape)

        // Critize the `generatedImage` through `criticModel`
        let CGz = criticModel(Gz)
        //print(criticProbability.shape)

        // Real image critic probability
        let Cx = criticModel(images)

        // Calculate the loss finally.
        //let loss = -(log(Cx) + log(1.0 - CGz)).mean()
        //var loss = Cx.mean()
        wassersteinDistance = (Cx - CGz).mean().scalarized()
        let loss = (CGz - Cx).mean()
        return loss
        //return softmaxCrossEntropy(logits: logits, labels: labels)
      }
      averageCriticLoss += criticLoss.scalarized()
      //trainingLossSum += loss.scalarized()
      trainingBatchCount += 1
      criticOptimizer.update(&criticModel.allDifferentiableVariables, along: criticGradients)
      
      // Clamp the parameters
      for kp in criticModel.recursivelyAllWritableKeyPaths(to: Tensor<Float>.self) {
        // Define high and low values
        let lowTensor = Tensor<Float>(repeating: lowClampValue, shape: criticModel[keyPath: kp].shape)
        let highTensor = Tensor<Float>(repeating: highClampValue, shape: criticModel[keyPath: kp].shape)
        // Adjust the parameters by clamping in range [lowTensor, highTensor]
        if criticModel[keyPath: kp] < lowTensor {
          criticModel[keyPath: kp] = lowTensor
        } else if criticModel[keyPath: kp] > highTensor {
          criticModel[keyPath: kp] = highTensor
        }
        // Let's check if it's done correctly.
        //print(min(lowTensor, criticModel[keyPath: kp]))
        //print(max(zerosTensor, criticModel[keyPath: kp]))
      }

    }
    // Average the criticLoss
    averageCriticLoss /= Float(numberOfCriticIterations)
    // Get all the criticLosses and Wasserstein distances
    criticLosses.append(averageCriticLoss)
    wassersteinDistances.append(wassersteinDistance)

    /*
     Train `generatorModel` one step
     */
    let (generatorLoss, generatorGradients) = valueWithGradient(at: generatorModel) {
      generatorModel -> Tensor<Float> in

      // Sample uniformly from normal distribution of [`batchSize`, `zLatent`] shaped `Tensor`
      zInput = Tensor<Float>(randomUniform: [batchSize, zLatent])
      //print(zInput.shape)

      // Forward pass `zInput` through `generatorModel`.
      let Gz = generatorModel(zInput) //.withoutDerivative()
      //print(generatedImage.shape)

      // Critize the `generatedImage` through `criticModel` withoutDerivative()
      let CGz = criticModel(Gz)//.withoutDerivative()
      //print(criticProbability.shape)

      // Calculate the loss finally.
      //let loss = log(1.0 - CGz).mean()
      let loss = -CGz.mean()
      return loss
    }
    generatorOptimizer.update(&generatorModel.allDifferentiableVariables, along: generatorGradients)
    generatorLosses.append(generatorLoss.scalarized())

    // Print statistics
    if iteration % 10 == 0{
      print("""
        Epoch: [\(epoch)/\(numberOfEpochs)] \
        iteration: \(iteration) \
        wassersteinDistance: \(wassersteinDistance) \
        criticLoss: \(averageCriticLoss) \
        generatorLoss: \(generatorLoss.scalarized())
        """)
    }
    
  }
  // Save the losses plot
  plt.plot(Array(1...wassersteinDistances.count),
           wassersteinDistances,
           "r-", label: "Wasserstein Distance")
  plt.plot(Array(1...criticLosses.count),
           criticLosses,
           "g-", label: "Critic Loss")
  plt.plot(Array(1...generatorLosses.count),
           generatorLosses,
           "b-", label: "Generator Loss")

  plt.xlabel("Iterations")
  plt.legend(loc: 9)
  plt.title("Wasserstein GAN in S4TF")

  plt.savefig("LossGraph.pdf")
  plt.close()
  
  var endTime = time.time()
  
  print("Took: \(endTime - startTime) s")
}

print("Finished. 🛬")
// Out:
// Started. 🛫
// Epoch: [1/5] iteration: 0 wassersteinDistance: 0.012591884 criticLoss: -0.012591884 generatorLoss: 0.00045472168
// Epoch: [1/5] iteration: 10 wassersteinDistance: 4.6538014e-05 criticLoss: -4.6538014e-05 generatorLoss: 0.0005876661
// Epoch: [1/5] iteration: 20 wassersteinDistance: -1.8906581e-05 criticLoss: 1.8906581e-05 generatorLoss: 0.00088533247
// Epoch: [1/5] iteration: 30 wassersteinDistance: -8.566382e-05 criticLoss: 8.566382e-05 generatorLoss: 0.0008633041
// Epoch: [1/5] iteration: 40 wassersteinDistance: 6.801309e-05 criticLoss: -6.801309e-05 generatorLoss: 0.00093450915
// Epoch: [1/5] iteration: 50 wassersteinDistance: -5.296575e-06 criticLoss: 5.296575e-06 generatorLoss: 0.00087156787
// Epoch: [1/5] iteration: 60 wassersteinDistance: -6.156739e-05 criticLoss: 6.156739e-05 generatorLoss: 0.00072640553
// Epoch: [1/5] iteration: 70 wassersteinDistance: -1.8690374e-05 criticLoss: 1.8690374e-05 generatorLoss: 0.00094254105
// Epoch: [1/5] iteration: 80 wassersteinDistance: 1.3872006e-05 criticLoss: -1.3872006e-05 generatorLoss: 0.0008547673
// Epoch: [1/5] iteration: 90 wassersteinDistance: 3.9796374e-05 criticLoss: -3.9796374e-05 generatorLoss: 0.0009572467
// Epoch: [1/5] iteration: 100 wassersteinDistance: 3.7908852e-05 criticLoss: -3.7908852e-05 generatorLoss: 0.0012911806
// Epoch: [1/5] iteration: 110 wassersteinDistance: 0.00011200138 criticLoss: -0.00011200138 generatorLoss: 0.0013517574
// Epoch: [1/5] iteration: 120 wassersteinDistance: 0.00015598869 criticLoss: -0.00015598869 generatorLoss: 0.0014580521
// Epoch: [1/5] iteration: 130 wassersteinDistance: 0.00023065606 criticLoss: -0.00023065606 generatorLoss: 0.0017200741
// Epoch: [1/5] iteration: 140 wassersteinDistance: 0.0006553863 criticLoss: -0.0006553863 generatorLoss: 0.0021530117
// Epoch: [1/5] iteration: 150 wassersteinDistance: 0.0008230371 criticLoss: -0.0008230371 generatorLoss: 0.0019600987
// Epoch: [1/5] iteration: 160 wassersteinDistance: 0.001872741 criticLoss: -0.001872741 generatorLoss: 0.0019048946
// Epoch: [1/5] iteration: 170 wassersteinDistance: 0.002135955 criticLoss: -0.002135955 generatorLoss: 0.001212035
// Epoch: [1/5] iteration: 180 wassersteinDistance: 0.002730513 criticLoss: -0.002730513 generatorLoss: -0.0008724578
// Epoch: [1/5] iteration: 190 wassersteinDistance: 0.0013126783 criticLoss: -0.0013126783 generatorLoss: -0.0031807665
// Epoch: [1/5] iteration: 200 wassersteinDistance: 0.0015046073 criticLoss: -0.0015046073 generatorLoss: -0.0030457606
// Epoch: [1/5] iteration: 210 wassersteinDistance: 0.0015153588 criticLoss: -0.0015153588 generatorLoss: -0.0037317968
// Epoch: [1/5] iteration: 220 wassersteinDistance: 0.0028063613 criticLoss: -0.0028063613 generatorLoss: -0.0058718026
// Epoch: [1/5] iteration: 230 wassersteinDistance: 0.003080158 criticLoss: -0.003080158 generatorLoss: -0.007209896
// Epoch: [1/5] iteration: 240 wassersteinDistance: 0.004104145 criticLoss: -0.004104145 generatorLoss: -0.0071970117
// Epoch: [1/5] iteration: 250 wassersteinDistance: 0.0032705134 criticLoss: -0.0032705134 generatorLoss: -0.008243238
// Epoch: [1/5] iteration: 260 wassersteinDistance: 0.004092811 criticLoss: -0.004092811 generatorLoss: -0.009671826
// Epoch: [1/5] iteration: 270 wassersteinDistance: 0.003694733 criticLoss: -0.003694733 generatorLoss: -0.008313083
// Epoch: [1/5] iteration: 280 wassersteinDistance: 0.0038716155 criticLoss: -0.0038716155 generatorLoss: -0.008120133
// Epoch: [1/5] iteration: 290 wassersteinDistance: 0.007278767 criticLoss: -0.007278767 generatorLoss: -0.009573073
// Epoch: [1/5] iteration: 300 wassersteinDistance: 0.004979686 criticLoss: -0.004979686 generatorLoss: -0.01211742
// Epoch: [1/5] iteration: 310 wassersteinDistance: 0.0048671914 criticLoss: -0.0048671914 generatorLoss: -0.01633678
// Epoch: [1/5] iteration: 320 wassersteinDistance: 0.002676736 criticLoss: -0.002676736 generatorLoss: -0.016453346
// Epoch: [1/5] iteration: 330 wassersteinDistance: 0.006025496 criticLoss: -0.006025496 generatorLoss: -0.023345757
// Epoch: [1/5] iteration: 340 wassersteinDistance: 0.008920462 criticLoss: -0.008920462 generatorLoss: -0.024177518
// Epoch: [1/5] iteration: 350 wassersteinDistance: 0.010024348 criticLoss: -0.010024348 generatorLoss: -0.02708122
// Epoch: [1/5] iteration: 360 wassersteinDistance: 0.0065205293 criticLoss: -0.0065205293 generatorLoss: -0.030526478
// Epoch: [1/5] iteration: 370 wassersteinDistance: 0.0094493935 criticLoss: -0.0094493935 generatorLoss: -0.032834396
// Epoch: [1/5] iteration: 380 wassersteinDistance: 0.013900411 criticLoss: -0.013900411 generatorLoss: -0.033633795
// Epoch: [1/5] iteration: 390 wassersteinDistance: 0.010875365 criticLoss: -0.010875365 generatorLoss: -0.038830545
// Epoch: [1/5] iteration: 400 wassersteinDistance: 0.010737469 criticLoss: -0.010737469 generatorLoss: -0.042083155
// Epoch: [1/5] iteration: 410 wassersteinDistance: 0.019420631 criticLoss: -0.019420631 generatorLoss: -0.0491983
// Epoch: [1/5] iteration: 420 wassersteinDistance: 0.0021513565 criticLoss: -0.0021513565 generatorLoss: -0.010427682
// Epoch: [1/5] iteration: 430 wassersteinDistance: 0.002261701 criticLoss: -0.002261701 generatorLoss: -0.0099644335
// Epoch: [1/5] iteration: 440 wassersteinDistance: 0.004288103 criticLoss: -0.004288103 generatorLoss: -0.010321451
// Epoch: [1/5] iteration: 450 wassersteinDistance: 0.0043131514 criticLoss: -0.0043131514 generatorLoss: -0.008822972
// Epoch: [1/5] iteration: 460 wassersteinDistance: 0.006393026 criticLoss: -0.006393026 generatorLoss: -0.007135665
// Epoch: [1/5] iteration: 470 wassersteinDistance: 0.004765462 criticLoss: -0.004765462 generatorLoss: -0.008242663
// Epoch: [1/5] iteration: 480 wassersteinDistance: 0.0077609355 criticLoss: -0.0077609355 generatorLoss: -0.014869159
// Epoch: [1/5] iteration: 490 wassersteinDistance: 0.0064443722 criticLoss: -0.0064443722 generatorLoss: -0.011626342
// Epoch: [1/5] iteration: 500 wassersteinDistance: 0.0052076667 criticLoss: -0.0052076667 generatorLoss: -0.00916338
// Epoch: [1/5] iteration: 510 wassersteinDistance: 0.007927954 criticLoss: -0.007927954 generatorLoss: -0.008546816
// Epoch: [1/5] iteration: 520 wassersteinDistance: 0.0028332614 criticLoss: -0.0028332614 generatorLoss: -0.004078995
// Epoch: [1/5] iteration: 530 wassersteinDistance: 0.00548986 criticLoss: -0.00548986 generatorLoss: -0.005018036
// Epoch: [1/5] iteration: 540 wassersteinDistance: 0.005888382 criticLoss: -0.005888382 generatorLoss: -0.0068082325
// Epoch: [1/5] iteration: 550 wassersteinDistance: 0.0068883696 criticLoss: -0.0068883696 generatorLoss: -0.011098087
// Epoch: [1/5] iteration: 560 wassersteinDistance: 0.009683944 criticLoss: -0.009683944 generatorLoss: -0.01174223
// Epoch: [1/5] iteration: 570 wassersteinDistance: 0.009793096 criticLoss: -0.009793096 generatorLoss: -0.015804876
// Epoch: [1/5] iteration: 580 wassersteinDistance: 0.0069937822 criticLoss: -0.0069937822 generatorLoss: -0.011815817
// Epoch: [1/5] iteration: 590 wassersteinDistance: 0.011266816 criticLoss: -0.011266816 generatorLoss: -0.009755362
// Epoch: [1/5] iteration: 600 wassersteinDistance: 0.01204169 criticLoss: -0.01204169 generatorLoss: -0.014957159
// Epoch: [1/5] iteration: 610 wassersteinDistance: 0.010920374 criticLoss: -0.010920374 generatorLoss: -0.011888316
// Epoch: [1/5] iteration: 620 wassersteinDistance: 0.011317485 criticLoss: -0.011317485 generatorLoss: -0.016980696
// Epoch: [1/5] iteration: 630 wassersteinDistance: 0.01730802 criticLoss: -0.01730802 generatorLoss: -0.023377806
// Epoch: [1/5] iteration: 640 wassersteinDistance: 0.01052963 criticLoss: -0.01052963 generatorLoss: -0.01918782
// Epoch: [1/5] iteration: 650 wassersteinDistance: 0.016256128 criticLoss: -0.016256128 generatorLoss: -0.023072561
// Epoch: [1/5] iteration: 660 wassersteinDistance: 0.015942698 criticLoss: -0.015942698 generatorLoss: -0.017341895
// Epoch: [1/5] iteration: 670 wassersteinDistance: 0.018362058 criticLoss: -0.018362058 generatorLoss: -0.014174541
// Epoch: [1/5] iteration: 680 wassersteinDistance: 0.02300853 criticLoss: -0.02300853 generatorLoss: -0.019891009
// Epoch: [1/5] iteration: 690 wassersteinDistance: 0.025792029 criticLoss: -0.025792029 generatorLoss: 0.00062765833
// Epoch: [1/5] iteration: 700 wassersteinDistance: 0.017270876 criticLoss: -0.017270876 generatorLoss: -0.006704474
// Epoch: [1/5] iteration: 710 wassersteinDistance: 0.019894842 criticLoss: -0.019894842 generatorLoss: -0.0028419383
// Epoch: [1/5] iteration: 720 wassersteinDistance: 0.014084836 criticLoss: -0.014084836 generatorLoss: -0.005596568
// Epoch: [1/5] iteration: 730 wassersteinDistance: 0.016700406 criticLoss: -0.016700406 generatorLoss: -0.00968044
// Epoch: [1/5] iteration: 740 wassersteinDistance: 0.032872945 criticLoss: -0.032872945 generatorLoss: -0.004725479
// Epoch: [1/5] iteration: 750 wassersteinDistance: 0.021363346 criticLoss: -0.021363346 generatorLoss: 0.0024812305
// Epoch: [1/5] iteration: 760 wassersteinDistance: 0.020814177 criticLoss: -0.020814177 generatorLoss: 0.0062433816
// Epoch: [1/5] iteration: 770 wassersteinDistance: 0.024369037 criticLoss: -0.024369037 generatorLoss: -0.0046764873
// Epoch: [1/5] iteration: 780 wassersteinDistance: 0.027481522 criticLoss: -0.027481522 generatorLoss: 0.010261592
// Shapes not compatible: [16, 32, 32, 3] != [64, 1]. Skipping
// Took: 270.4913499355316 s
// Epoch: [2/5] iteration: 0 wassersteinDistance: 0.024529502 criticLoss: -0.024529502 generatorLoss: 0.012424575
// Epoch: [2/5] iteration: 10 wassersteinDistance: 0.026732624 criticLoss: -0.026732624 generatorLoss: 0.00618032
// Epoch: [2/5] iteration: 20 wassersteinDistance: 0.039255496 criticLoss: -0.039255496 generatorLoss: 0.013879655
// Epoch: [2/5] iteration: 30 wassersteinDistance: 0.037481662 criticLoss: -0.037481662 generatorLoss: 0.023678675
// Epoch: [2/5] iteration: 40 wassersteinDistance: 0.02963847 criticLoss: -0.02963847 generatorLoss: 0.032691456
// Epoch: [2/5] iteration: 50 wassersteinDistance: 0.040837824 criticLoss: -0.040837824 generatorLoss: 0.035378955
// Epoch: [2/5] iteration: 60 wassersteinDistance: 0.037466012 criticLoss: -0.037466012 generatorLoss: 0.0348308
// Epoch: [2/5] iteration: 70 wassersteinDistance: 0.030740201 criticLoss: -0.030740201 generatorLoss: 0.053181827
// Epoch: [2/5] iteration: 80 wassersteinDistance: 0.047464795 criticLoss: -0.047464795 generatorLoss: 0.066701695
// Epoch: [2/5] iteration: 90 wassersteinDistance: 0.051262792 criticLoss: -0.051262792 generatorLoss: 0.05935695
// Epoch: [2/5] iteration: 100 wassersteinDistance: 0.060527936 criticLoss: -0.060527936 generatorLoss: 0.05616858
// Epoch: [2/5] iteration: 110 wassersteinDistance: 0.08134034 criticLoss: -0.08134034 generatorLoss: 0.06854541
// Epoch: [2/5] iteration: 120 wassersteinDistance: 0.08216189 criticLoss: -0.08216189 generatorLoss: 0.111628205
// Epoch: [2/5] iteration: 130 wassersteinDistance: 0.08040809 criticLoss: -0.08040809 generatorLoss: 0.12320151
// Epoch: [2/5] iteration: 140 wassersteinDistance: 0.06554794 criticLoss: -0.06554794 generatorLoss: 0.14063056
// Epoch: [2/5] iteration: 150 wassersteinDistance: 0.08708977 criticLoss: -0.08708977 generatorLoss: 0.1352321
// Epoch: [2/5] iteration: 160 wassersteinDistance: 0.09306076 criticLoss: -0.09306076 generatorLoss: 0.14919846
// Epoch: [2/5] iteration: 170 wassersteinDistance: 0.10697633 criticLoss: -0.10697633 generatorLoss: 0.18152368
// Epoch: [2/5] iteration: 180 wassersteinDistance: 0.13351855 criticLoss: -0.13351855 generatorLoss: 0.17082137
// Epoch: [2/5] iteration: 190 wassersteinDistance: 0.13724992 criticLoss: -0.13724992 generatorLoss: 0.21654563
// Epoch: [2/5] iteration: 200 wassersteinDistance: 0.13414606 criticLoss: -0.13414606 generatorLoss: 0.24001953
// Epoch: [2/5] iteration: 210 wassersteinDistance: 0.16197121 criticLoss: -0.16197121 generatorLoss: 0.244768
// Epoch: [2/5] iteration: 220 wassersteinDistance: 0.17177206 criticLoss: -0.17177206 generatorLoss: 0.26103514
// Epoch: [2/5] iteration: 230 wassersteinDistance: 0.17589061 criticLoss: -0.17589061 generatorLoss: 0.28649306
// Epoch: [2/5] iteration: 240 wassersteinDistance: 0.22115564 criticLoss: -0.22115564 generatorLoss: 0.29142275
// Epoch: [2/5] iteration: 250 wassersteinDistance: 0.22313702 criticLoss: -0.22313702 generatorLoss: 0.31318504
// Epoch: [2/5] iteration: 260 wassersteinDistance: 0.24796885 criticLoss: -0.24796885 generatorLoss: 0.37565845
// Epoch: [2/5] iteration: 270 wassersteinDistance: 0.25604844 criticLoss: -0.25604844 generatorLoss: 0.42888808
// Epoch: [2/5] iteration: 280 wassersteinDistance: 0.31744778 criticLoss: -0.31744778 generatorLoss: 0.41719237
// Epoch: [2/5] iteration: 290 wassersteinDistance: 0.29579884 criticLoss: -0.29579884 generatorLoss: 0.47848243
// Epoch: [2/5] iteration: 300 wassersteinDistance: 0.38480997 criticLoss: -0.38480997 generatorLoss: 0.44982705
// Epoch: [2/5] iteration: 310 wassersteinDistance: 0.39737815 criticLoss: -0.39737815 generatorLoss: 0.48933175
// Epoch: [2/5] iteration: 320 wassersteinDistance: 0.38934636 criticLoss: -0.38934636 generatorLoss: 0.5681801
// Epoch: [2/5] iteration: 330 wassersteinDistance: 0.36601865 criticLoss: -0.36601865 generatorLoss: 0.5546862
// Epoch: [2/5] iteration: 340 wassersteinDistance: 0.42323193 criticLoss: -0.42323193 generatorLoss: 0.61564213
// Epoch: [2/5] iteration: 350 wassersteinDistance: 0.37263352 criticLoss: -0.37263352 generatorLoss: 0.60643
// Epoch: [2/5] iteration: 360 wassersteinDistance: 0.30059755 criticLoss: -0.30059755 generatorLoss: 0.5852448
// Epoch: [2/5] iteration: 370 wassersteinDistance: 0.4223863 criticLoss: -0.4223863 generatorLoss: 0.5720296
// Epoch: [2/5] iteration: 380 wassersteinDistance: 0.53383493 criticLoss: -0.53383493 generatorLoss: 0.6070583
// Epoch: [2/5] iteration: 390 wassersteinDistance: 0.49711007 criticLoss: -0.49711007 generatorLoss: 0.6226131
// Epoch: [2/5] iteration: 400 wassersteinDistance: 0.4763307 criticLoss: -0.4763307 generatorLoss: 0.6768317
// Epoch: [2/5] iteration: 410 wassersteinDistance: 0.52680004 criticLoss: -0.52680004 generatorLoss: 0.669872
// Epoch: [2/5] iteration: 420 wassersteinDistance: 0.5399213 criticLoss: -0.5399213 generatorLoss: 0.7421012
// Epoch: [2/5] iteration: 430 wassersteinDistance: 0.5648898 criticLoss: -0.5648898 generatorLoss: 0.71533644
// Epoch: [2/5] iteration: 440 wassersteinDistance: 0.6227645 criticLoss: -0.6227645 generatorLoss: 0.69030577
// Epoch: [2/5] iteration: 450 wassersteinDistance: 0.66015923 criticLoss: -0.66015923 generatorLoss: 0.77344716
// Epoch: [2/5] iteration: 460 wassersteinDistance: 0.66232896 criticLoss: -0.66232896 generatorLoss: 0.7194612
// Epoch: [2/5] iteration: 470 wassersteinDistance: 0.5968051 criticLoss: -0.5968051 generatorLoss: 0.7981112
// Epoch: [2/5] iteration: 480 wassersteinDistance: 0.721318 criticLoss: -0.721318 generatorLoss: 0.76661223
// Epoch: [2/5] iteration: 490 wassersteinDistance: 0.6719326 criticLoss: -0.6719326 generatorLoss: 0.7854359
// Epoch: [2/5] iteration: 500 wassersteinDistance: 0.81641513 criticLoss: -0.81641513 generatorLoss: 0.86135054
// Epoch: [2/5] iteration: 510 wassersteinDistance: 0.78611547 criticLoss: -0.78611547 generatorLoss: 0.863922
// Epoch: [2/5] iteration: 520 wassersteinDistance: 0.9037086 criticLoss: -0.9037086 generatorLoss: 0.7872211
// Epoch: [2/5] iteration: 530 wassersteinDistance: 0.94531435 criticLoss: -0.94531435 generatorLoss: 0.9025495
// Epoch: [2/5] iteration: 540 wassersteinDistance: 0.6917959 criticLoss: -0.6917959 generatorLoss: 0.88010377
// Epoch: [2/5] iteration: 550 wassersteinDistance: 0.9190128 criticLoss: -0.9190128 generatorLoss: 0.9434959
// Epoch: [2/5] iteration: 560 wassersteinDistance: 0.7698487 criticLoss: -0.7698487 generatorLoss: 0.93343204
// Epoch: [2/5] iteration: 570 wassersteinDistance: 0.9586446 criticLoss: -0.9586446 generatorLoss: 0.8849772
// Epoch: [2/5] iteration: 580 wassersteinDistance: 0.98116314 criticLoss: -0.98116314 generatorLoss: 0.92765325
// Epoch: [2/5] iteration: 590 wassersteinDistance: 1.0199497 criticLoss: -1.0199497 generatorLoss: 0.9024472
// Epoch: [2/5] iteration: 600 wassersteinDistance: 0.84771025 criticLoss: -0.84771025 generatorLoss: 1.0280912
// Epoch: [2/5] iteration: 610 wassersteinDistance: 1.0997825 criticLoss: -1.0997825 generatorLoss: 0.90129775
// Epoch: [2/5] iteration: 620 wassersteinDistance: 0.89630187 criticLoss: -0.89630187 generatorLoss: 1.0599982
// Epoch: [2/5] iteration: 630 wassersteinDistance: 1.0553291 criticLoss: -1.0553291 generatorLoss: 1.0059357
// Epoch: [2/5] iteration: 640 wassersteinDistance: 1.1267359 criticLoss: -1.1267359 generatorLoss: 1.0577008
// Epoch: [2/5] iteration: 650 wassersteinDistance: 1.1297612 criticLoss: -1.1297612 generatorLoss: 1.0209706
// Epoch: [2/5] iteration: 660 wassersteinDistance: 1.3790582 criticLoss: -1.3790582 generatorLoss: 1.0599461
// Epoch: [2/5] iteration: 670 wassersteinDistance: 1.1267514 criticLoss: -1.1267514 generatorLoss: 1.0850289
// Epoch: [2/5] iteration: 680 wassersteinDistance: 1.3508571 criticLoss: -1.3508571 generatorLoss: 1.118939
// Epoch: [2/5] iteration: 690 wassersteinDistance: 1.3782248 criticLoss: -1.3782248 generatorLoss: 1.0847194
// Epoch: [2/5] iteration: 700 wassersteinDistance: 1.1963658 criticLoss: -1.1963658 generatorLoss: 1.0602263
// Epoch: [2/5] iteration: 710 wassersteinDistance: 1.5312421 criticLoss: -1.5312421 generatorLoss: 1.2421038
// Epoch: [2/5] iteration: 720 wassersteinDistance: 1.517093 criticLoss: -1.517093 generatorLoss: 1.1613073
// Epoch: [2/5] iteration: 730 wassersteinDistance: 1.3022487 criticLoss: -1.3022487 generatorLoss: 1.1793848
// Epoch: [2/5] iteration: 740 wassersteinDistance: 1.3184494 criticLoss: -1.3184494 generatorLoss: 1.191712
// Epoch: [2/5] iteration: 750 wassersteinDistance: 1.5509022 criticLoss: -1.5509022 generatorLoss: 1.1194983
// Epoch: [2/5] iteration: 760 wassersteinDistance: 1.4263399 criticLoss: -1.4263399 generatorLoss: 1.2138634
// Epoch: [2/5] iteration: 770 wassersteinDistance: 1.4923102 criticLoss: -1.4923102 generatorLoss: 1.2530489
// Epoch: [2/5] iteration: 780 wassersteinDistance: 1.5944974 criticLoss: -1.5944974 generatorLoss: 1.2897196
// Shapes not compatible: [16, 32, 32, 3] != [64, 1]. Skipping
// Took: 259.4219124317169 s
// Epoch: [3/5] iteration: 0 wassersteinDistance: 1.1910406 criticLoss: -1.1910406 generatorLoss: 1.2420115
// Epoch: [3/5] iteration: 10 wassersteinDistance: 1.3922659 criticLoss: -1.3922659 generatorLoss: 1.2148689
// Epoch: [3/5] iteration: 20 wassersteinDistance: 1.3353052 criticLoss: -1.3353052 generatorLoss: 1.2666252
// Epoch: [3/5] iteration: 30 wassersteinDistance: 1.2795091 criticLoss: -1.2795091 generatorLoss: 1.1645156
// Epoch: [3/5] iteration: 40 wassersteinDistance: 1.6218282 criticLoss: -1.6218282 generatorLoss: 1.1752074
// Epoch: [3/5] iteration: 50 wassersteinDistance: 1.7994726 criticLoss: -1.7994726 generatorLoss: 1.3253547
// Epoch: [3/5] iteration: 60 wassersteinDistance: 1.409243 criticLoss: -1.409243 generatorLoss: 1.3683574
// Epoch: [3/5] iteration: 70 wassersteinDistance: 1.7198842 criticLoss: -1.7198842 generatorLoss: 1.3248327
// Epoch: [3/5] iteration: 80 wassersteinDistance: 1.661283 criticLoss: -1.661283 generatorLoss: 1.2774577
// Epoch: [3/5] iteration: 90 wassersteinDistance: 1.5276339 criticLoss: -1.5276339 generatorLoss: 1.1993883
// Epoch: [3/5] iteration: 100 wassersteinDistance: 1.7186022 criticLoss: -1.7186022 generatorLoss: 1.1515362
// Epoch: [3/5] iteration: 110 wassersteinDistance: 1.3214226 criticLoss: -1.3214226 generatorLoss: 0.95394576
// Epoch: [3/5] iteration: 120 wassersteinDistance: 1.3695803 criticLoss: -1.3695803 generatorLoss: 1.1317086
// Epoch: [3/5] iteration: 130 wassersteinDistance: 1.4192529 criticLoss: -1.4192529 generatorLoss: 1.3181716
// Epoch: [3/5] iteration: 140 wassersteinDistance: 1.723347 criticLoss: -1.723347 generatorLoss: 1.3077351
// Epoch: [3/5] iteration: 150 wassersteinDistance: 1.5806457 criticLoss: -1.5806457 generatorLoss: 1.3393235
// Epoch: [3/5] iteration: 160 wassersteinDistance: 1.3655784 criticLoss: -1.3655784 generatorLoss: 1.4344745
// Epoch: [3/5] iteration: 170 wassersteinDistance: 1.6298711 criticLoss: -1.6298711 generatorLoss: 1.3798857
// Epoch: [3/5] iteration: 180 wassersteinDistance: 1.667978 criticLoss: -1.667978 generatorLoss: 1.0076888
// Epoch: [3/5] iteration: 190 wassersteinDistance: 1.4935039 criticLoss: -1.4935039 generatorLoss: 0.941115
// Epoch: [3/5] iteration: 200 wassersteinDistance: 1.6628984 criticLoss: -1.6628984 generatorLoss: 1.2045822
// Epoch: [3/5] iteration: 210 wassersteinDistance: 1.6188569 criticLoss: -1.6188569 generatorLoss: 1.4122376
// Epoch: [3/5] iteration: 220 wassersteinDistance: 1.5918452 criticLoss: -1.5918452 generatorLoss: 1.1486915
// Epoch: [3/5] iteration: 230 wassersteinDistance: 1.517562 criticLoss: -1.517562 generatorLoss: 1.3093145
// Epoch: [3/5] iteration: 240 wassersteinDistance: 1.9605501 criticLoss: -1.9605501 generatorLoss: 1.2311084
// Epoch: [3/5] iteration: 250 wassersteinDistance: 1.6215495 criticLoss: -1.6215495 generatorLoss: 1.3369913
// Epoch: [3/5] iteration: 260 wassersteinDistance: 1.9991255 criticLoss: -1.9991255 generatorLoss: 1.4292927
// Epoch: [3/5] iteration: 270 wassersteinDistance: 1.9558084 criticLoss: -1.9558084 generatorLoss: 1.5153364
// Epoch: [3/5] iteration: 280 wassersteinDistance: 1.9097488 criticLoss: -1.9097488 generatorLoss: 1.4913371
// Epoch: [3/5] iteration: 290 wassersteinDistance: 1.8535457 criticLoss: -1.8535457 generatorLoss: 1.3169042
// Epoch: [3/5] iteration: 300 wassersteinDistance: 1.5577743 criticLoss: -1.5577743 generatorLoss: 1.3272728
// Epoch: [3/5] iteration: 310 wassersteinDistance: 1.7228273 criticLoss: -1.7228273 generatorLoss: 1.3705436
// Epoch: [3/5] iteration: 320 wassersteinDistance: 1.6305227 criticLoss: -1.6305227 generatorLoss: 1.3927764
// Epoch: [3/5] iteration: 330 wassersteinDistance: 1.1026142 criticLoss: -1.1026142 generatorLoss: 1.2772043
// Epoch: [3/5] iteration: 340 wassersteinDistance: 1.4234942 criticLoss: -1.4234942 generatorLoss: 1.3642131
// Epoch: [3/5] iteration: 350 wassersteinDistance: 1.4741241 criticLoss: -1.4741241 generatorLoss: 1.6410519
// Epoch: [3/5] iteration: 360 wassersteinDistance: 1.9531275 criticLoss: -1.9531275 generatorLoss: 1.7335324
// Epoch: [3/5] iteration: 370 wassersteinDistance: 1.8047915 criticLoss: -1.8047915 generatorLoss: 1.6797491
// Epoch: [3/5] iteration: 380 wassersteinDistance: 1.7525532 criticLoss: -1.7525532 generatorLoss: 1.6537715
// Epoch: [3/5] iteration: 390 wassersteinDistance: 1.982474 criticLoss: -1.982474 generatorLoss: 1.7153151
// Epoch: [3/5] iteration: 400 wassersteinDistance: 2.2710576 criticLoss: -2.2710576 generatorLoss: 1.8249878
// Epoch: [3/5] iteration: 410 wassersteinDistance: 1.938067 criticLoss: -1.938067 generatorLoss: 1.4137397
// Epoch: [3/5] iteration: 420 wassersteinDistance: 1.4867388 criticLoss: -1.4867388 generatorLoss: 1.6587698
// Epoch: [3/5] iteration: 430 wassersteinDistance: 2.081076 criticLoss: -2.081076 generatorLoss: 1.598767
// Epoch: [3/5] iteration: 440 wassersteinDistance: 1.8745366 criticLoss: -1.8745366 generatorLoss: 1.4662404
// Epoch: [3/5] iteration: 450 wassersteinDistance: 2.259564 criticLoss: -2.259564 generatorLoss: 1.6267294
// Epoch: [3/5] iteration: 460 wassersteinDistance: 1.8605049 criticLoss: -1.8605049 generatorLoss: 1.4321556
// Epoch: [3/5] iteration: 470 wassersteinDistance: 1.9506983 criticLoss: -1.9506983 generatorLoss: 1.6097224
// Epoch: [3/5] iteration: 480 wassersteinDistance: 1.8101246 criticLoss: -1.8101246 generatorLoss: 1.6308575
// Epoch: [3/5] iteration: 490 wassersteinDistance: 2.0722678 criticLoss: -2.0722678 generatorLoss: 1.4439876
// Epoch: [3/5] iteration: 500 wassersteinDistance: 1.6742303 criticLoss: -1.6742303 generatorLoss: 1.7257674
// Epoch: [3/5] iteration: 510 wassersteinDistance: 1.8632984 criticLoss: -1.8632984 generatorLoss: 1.7100589
// Epoch: [3/5] iteration: 520 wassersteinDistance: 2.0339432 criticLoss: -2.0339432 generatorLoss: 1.5258863
// Epoch: [3/5] iteration: 530 wassersteinDistance: 2.495072 criticLoss: -2.495072 generatorLoss: 1.6889561
// Epoch: [3/5] iteration: 540 wassersteinDistance: 1.7501509 criticLoss: -1.7501509 generatorLoss: 1.4360183
// Epoch: [3/5] iteration: 550 wassersteinDistance: 1.993181 criticLoss: -1.993181 generatorLoss: 1.5722044
// Epoch: [3/5] iteration: 560 wassersteinDistance: 2.0862627 criticLoss: -2.0862627 generatorLoss: 1.5417547
// Epoch: [3/5] iteration: 570 wassersteinDistance: 2.3551512 criticLoss: -2.3551512 generatorLoss: 1.7191005
// Epoch: [3/5] iteration: 580 wassersteinDistance: 2.263702 criticLoss: -2.263702 generatorLoss: 1.7152286
// Epoch: [3/5] iteration: 590 wassersteinDistance: 2.10115 criticLoss: -2.10115 generatorLoss: 1.6837225
// Epoch: [3/5] iteration: 600 wassersteinDistance: 2.3406115 criticLoss: -2.3406115 generatorLoss: 1.6718199
// Epoch: [3/5] iteration: 610 wassersteinDistance: 2.3777618 criticLoss: -2.3777618 generatorLoss: 1.523267
// Epoch: [3/5] iteration: 620 wassersteinDistance: 2.217601 criticLoss: -2.217601 generatorLoss: 1.4444864
// Epoch: [3/5] iteration: 630 wassersteinDistance: 2.1564918 criticLoss: -2.1564918 generatorLoss: 1.8320163
// Epoch: [3/5] iteration: 640 wassersteinDistance: 2.38747 criticLoss: -2.38747 generatorLoss: 1.8863192
// Epoch: [3/5] iteration: 650 wassersteinDistance: 2.6377773 criticLoss: -2.6377773 generatorLoss: 1.8929554
// Epoch: [3/5] iteration: 660 wassersteinDistance: 2.6923184 criticLoss: -2.6923184 generatorLoss: 1.8098896
// Epoch: [3/5] iteration: 670 wassersteinDistance: 2.9544308 criticLoss: -2.9544308 generatorLoss: 1.9521832
// Epoch: [3/5] iteration: 680 wassersteinDistance: 1.8226236 criticLoss: -1.8226236 generatorLoss: 1.5102551
// Epoch: [3/5] iteration: 690 wassersteinDistance: 2.1819293 criticLoss: -2.1819293 generatorLoss: 1.9832292
// Epoch: [3/5] iteration: 700 wassersteinDistance: 2.6978405 criticLoss: -2.6978405 generatorLoss: 2.1087327
// Epoch: [3/5] iteration: 710 wassersteinDistance: 3.0194602 criticLoss: -3.0194602 generatorLoss: 2.1331306
// Epoch: [3/5] iteration: 720 wassersteinDistance: 3.0556285 criticLoss: -3.0556285 generatorLoss: 2.0104253
// Epoch: [3/5] iteration: 730 wassersteinDistance: 1.8944223 criticLoss: -1.8944223 generatorLoss: 1.1347634
// Epoch: [3/5] iteration: 740 wassersteinDistance: 1.2293141 criticLoss: -1.2293141 generatorLoss: 1.0768534
// Epoch: [3/5] iteration: 750 wassersteinDistance: 2.4428933 criticLoss: -2.4428933 generatorLoss: 1.9593133
// Epoch: [3/5] iteration: 760 wassersteinDistance: 2.1878886 criticLoss: -2.1878886 generatorLoss: 2.0218606
// Epoch: [3/5] iteration: 770 wassersteinDistance: 2.1003032 criticLoss: -2.1003032 generatorLoss: 1.4793673
// Epoch: [3/5] iteration: 780 wassersteinDistance: 1.846616 criticLoss: -1.846616 generatorLoss: 1.4378694
// Shapes not compatible: [16, 32, 32, 3] != [64, 1]. Skipping
// Took: 255.5297601222992 s
// Epoch: [4/5] iteration: 0 wassersteinDistance: 2.0765495 criticLoss: -2.0765495 generatorLoss: 1.3568131
// Epoch: [4/5] iteration: 10 wassersteinDistance: 2.4850512 criticLoss: -2.4850512 generatorLoss: 1.5215222
// Epoch: [4/5] iteration: 20 wassersteinDistance: 2.4601476 criticLoss: -2.4601476 generatorLoss: 1.3813133
// Epoch: [4/5] iteration: 30 wassersteinDistance: 2.314876 criticLoss: -2.314876 generatorLoss: 1.663082
// Epoch: [4/5] iteration: 40 wassersteinDistance: 2.5754428 criticLoss: -2.5754428 generatorLoss: 1.8032708
// Epoch: [4/5] iteration: 50 wassersteinDistance: 2.7935195 criticLoss: -2.7935195 generatorLoss: 1.8671646
// Epoch: [4/5] iteration: 60 wassersteinDistance: 2.7578983 criticLoss: -2.7578983 generatorLoss: 2.0257125
// Epoch: [4/5] iteration: 70 wassersteinDistance: 2.7313638 criticLoss: -2.7313638 generatorLoss: 2.0048618
// Epoch: [4/5] iteration: 80 wassersteinDistance: 2.585281 criticLoss: -2.585281 generatorLoss: 1.8973871
// Epoch: [4/5] iteration: 90 wassersteinDistance: 2.71565 criticLoss: -2.71565 generatorLoss: 1.9183078
// Epoch: [4/5] iteration: 100 wassersteinDistance: 2.8426147 criticLoss: -2.8426147 generatorLoss: 1.8990208
// Epoch: [4/5] iteration: 110 wassersteinDistance: 2.7728074 criticLoss: -2.7728074 generatorLoss: 1.8140957
// Epoch: [4/5] iteration: 120 wassersteinDistance: 2.4317129 criticLoss: -2.4317129 generatorLoss: 1.9462955
// Epoch: [4/5] iteration: 130 wassersteinDistance: 3.0329368 criticLoss: -3.0329368 generatorLoss: 2.0218446
// Epoch: [4/5] iteration: 140 wassersteinDistance: 2.4640489 criticLoss: -2.4640489 generatorLoss: 1.5493742
// Epoch: [4/5] iteration: 150 wassersteinDistance: 2.5098057 criticLoss: -2.5098057 generatorLoss: 1.9284197
// Epoch: [4/5] iteration: 160 wassersteinDistance: 2.6009421 criticLoss: -2.6009421 generatorLoss: 2.1718225
// Epoch: [4/5] iteration: 170 wassersteinDistance: 2.6140935 criticLoss: -2.6140935 generatorLoss: 1.9194903
// Epoch: [4/5] iteration: 180 wassersteinDistance: 2.0973415 criticLoss: -2.0973415 generatorLoss: 1.4749274
// Epoch: [4/5] iteration: 190 wassersteinDistance: 2.5711014 criticLoss: -2.5711014 generatorLoss: 1.6815449
// Epoch: [4/5] iteration: 200 wassersteinDistance: 2.7179222 criticLoss: -2.7179222 generatorLoss: 1.8146822
// Epoch: [4/5] iteration: 210 wassersteinDistance: 2.6234882 criticLoss: -2.6234882 generatorLoss: 1.8704654
// Epoch: [4/5] iteration: 220 wassersteinDistance: 2.7055483 criticLoss: -2.7055483 generatorLoss: 1.9277109
// Epoch: [4/5] iteration: 230 wassersteinDistance: 2.9734337 criticLoss: -2.9734337 generatorLoss: 1.9041238
// Epoch: [4/5] iteration: 240 wassersteinDistance: 2.951008 criticLoss: -2.951008 generatorLoss: 1.862515
// Epoch: [4/5] iteration: 250 wassersteinDistance: 2.42344 criticLoss: -2.42344 generatorLoss: 1.9467285
// Epoch: [4/5] iteration: 260 wassersteinDistance: 2.355606 criticLoss: -2.355606 generatorLoss: 1.9240707
// Epoch: [4/5] iteration: 270 wassersteinDistance: 2.4793274 criticLoss: -2.4793274 generatorLoss: 1.7635733
// Epoch: [4/5] iteration: 280 wassersteinDistance: 3.0755055 criticLoss: -3.0755055 generatorLoss: 2.013768
// Epoch: [4/5] iteration: 290 wassersteinDistance: 2.9456706 criticLoss: -2.9456706 generatorLoss: 1.8588307
// Epoch: [4/5] iteration: 300 wassersteinDistance: 2.6092541 criticLoss: -2.6092541 generatorLoss: 1.9844943
// Epoch: [4/5] iteration: 310 wassersteinDistance: 2.9956765 criticLoss: -2.9956765 generatorLoss: 2.0440366
// Epoch: [4/5] iteration: 320 wassersteinDistance: 2.8091462 criticLoss: -2.8091462 generatorLoss: 2.0137486
// Epoch: [4/5] iteration: 330 wassersteinDistance: 2.2051 criticLoss: -2.2051 generatorLoss: 1.7974827
// Epoch: [4/5] iteration: 340 wassersteinDistance: 2.7737489 criticLoss: -2.7737489 generatorLoss: 2.160945
// Epoch: [4/5] iteration: 350 wassersteinDistance: 2.2820659 criticLoss: -2.2820659 generatorLoss: 1.7127666
// Epoch: [4/5] iteration: 360 wassersteinDistance: 1.923662 criticLoss: -1.923662 generatorLoss: 1.8833783
// Epoch: [4/5] iteration: 370 wassersteinDistance: 2.5061293 criticLoss: -2.5061293 generatorLoss: 1.7774926
// Epoch: [4/5] iteration: 380 wassersteinDistance: 2.7921162 criticLoss: -2.7921162 generatorLoss: 1.8457797
// Epoch: [4/5] iteration: 390 wassersteinDistance: 3.2341928 criticLoss: -3.2341928 generatorLoss: 2.071515
// Epoch: [4/5] iteration: 400 wassersteinDistance: 2.7527223 criticLoss: -2.7527223 generatorLoss: 1.8961769
// Epoch: [4/5] iteration: 410 wassersteinDistance: 3.0586696 criticLoss: -3.0586696 generatorLoss: 1.9551172
// Epoch: [4/5] iteration: 420 wassersteinDistance: 3.0142922 criticLoss: -3.0142922 generatorLoss: 2.0467238
// Epoch: [4/5] iteration: 430 wassersteinDistance: 3.128634 criticLoss: -3.128634 generatorLoss: 2.0503538
// Epoch: [4/5] iteration: 440 wassersteinDistance: 2.5595036 criticLoss: -2.5595036 generatorLoss: 1.7048391
// Epoch: [4/5] iteration: 450 wassersteinDistance: 2.2393932 criticLoss: -2.2393932 generatorLoss: 1.1933025
// Epoch: [4/5] iteration: 460 wassersteinDistance: 2.628394 criticLoss: -2.628394 generatorLoss: 1.4164498
// Epoch: [4/5] iteration: 470 wassersteinDistance: 2.7556386 criticLoss: -2.7556386 generatorLoss: 1.7579708
// Epoch: [4/5] iteration: 480 wassersteinDistance: 2.8870728 criticLoss: -2.8870728 generatorLoss: 1.7446336
// Epoch: [4/5] iteration: 490 wassersteinDistance: 3.6070042 criticLoss: -3.6070042 generatorLoss: 1.7790388
// Epoch: [4/5] iteration: 500 wassersteinDistance: 2.7492406 criticLoss: -2.7492406 generatorLoss: 1.4795024
// Epoch: [4/5] iteration: 510 wassersteinDistance: 3.2098646 criticLoss: -3.2098646 generatorLoss: 2.451122
// Epoch: [4/5] iteration: 520 wassersteinDistance: 3.3670955 criticLoss: -3.3670955 generatorLoss: 1.99144
// Epoch: [4/5] iteration: 530 wassersteinDistance: 3.774629 criticLoss: -3.774629 generatorLoss: 2.3919811
// Epoch: [4/5] iteration: 540 wassersteinDistance: 2.9096327 criticLoss: -2.9096327 generatorLoss: 2.2369463
// Epoch: [4/5] iteration: 550 wassersteinDistance: 2.7880383 criticLoss: -2.7880383 generatorLoss: 2.0838277
// Epoch: [4/5] iteration: 560 wassersteinDistance: 3.1803455 criticLoss: -3.1803455 generatorLoss: 2.0269563
// Epoch: [4/5] iteration: 570 wassersteinDistance: 3.0835872 criticLoss: -3.0835872 generatorLoss: 1.640034
// Epoch: [4/5] iteration: 580 wassersteinDistance: 3.3433433 criticLoss: -3.3433433 generatorLoss: 1.969676
// Epoch: [4/5] iteration: 590 wassersteinDistance: 3.1631484 criticLoss: -3.1631484 generatorLoss: 2.1382234
// Epoch: [4/5] iteration: 600 wassersteinDistance: 2.9755745 criticLoss: -2.9755745 generatorLoss: 1.932432
// Epoch: [4/5] iteration: 610 wassersteinDistance: 3.3336267 criticLoss: -3.3336267 generatorLoss: 2.1211817
// Epoch: [4/5] iteration: 620 wassersteinDistance: 3.4989314 criticLoss: -3.4989314 generatorLoss: 2.1219497
// Epoch: [4/5] iteration: 630 wassersteinDistance: 2.8225474 criticLoss: -2.8225474 generatorLoss: 1.8070717
// Epoch: [4/5] iteration: 640 wassersteinDistance: 2.7800295 criticLoss: -2.7800295 generatorLoss: 1.4030638
// Epoch: [4/5] iteration: 650 wassersteinDistance: 3.3387098 criticLoss: -3.3387098 generatorLoss: 1.9429798
// Epoch: [4/5] iteration: 660 wassersteinDistance: 2.868298 criticLoss: -2.868298 generatorLoss: 1.8341959
// Epoch: [4/5] iteration: 670 wassersteinDistance: 3.3797507 criticLoss: -3.3797507 generatorLoss: 2.3106308
// Epoch: [4/5] iteration: 680 wassersteinDistance: 3.1568878 criticLoss: -3.1568878 generatorLoss: 1.957582
// Epoch: [4/5] iteration: 690 wassersteinDistance: 3.4139779 criticLoss: -3.4139779 generatorLoss: 2.248386
// Epoch: [4/5] iteration: 700 wassersteinDistance: 3.4355211 criticLoss: -3.4355211 generatorLoss: 2.300146
// Epoch: [4/5] iteration: 710 wassersteinDistance: 3.3304722 criticLoss: -3.3304722 generatorLoss: 2.0530276
// Epoch: [4/5] iteration: 720 wassersteinDistance: 3.7764432 criticLoss: -3.7764432 generatorLoss: 2.3180933
// Epoch: [4/5] iteration: 730 wassersteinDistance: 3.2465358 criticLoss: -3.2465358 generatorLoss: 2.0352511
// Epoch: [4/5] iteration: 740 wassersteinDistance: 3.7214289 criticLoss: -3.7214289 generatorLoss: 1.9575691
// Epoch: [4/5] iteration: 750 wassersteinDistance: 3.6947637 criticLoss: -3.6947637 generatorLoss: 2.1996732
// Epoch: [4/5] iteration: 760 wassersteinDistance: 3.0996704 criticLoss: -3.0996704 generatorLoss: 1.73264
// Epoch: [4/5] iteration: 770 wassersteinDistance: 3.9435987 criticLoss: -3.9435987 generatorLoss: 2.5159912
// Epoch: [4/5] iteration: 780 wassersteinDistance: 2.9151344 criticLoss: -2.9151344 generatorLoss: 1.5481927
// Shapes not compatible: [16, 32, 32, 3] != [64, 1]. Skipping
// Took: 256.76939058303833 s
// Epoch: [5/5] iteration: 0 wassersteinDistance: 2.8824115 criticLoss: -2.8824115 generatorLoss: 1.8303111
// Epoch: [5/5] iteration: 10 wassersteinDistance: 3.5964465 criticLoss: -3.5964465 generatorLoss: 1.9418844
// Epoch: [5/5] iteration: 20 wassersteinDistance: 3.1686242 criticLoss: -3.1686242 generatorLoss: 1.8211415
// Epoch: [5/5] iteration: 30 wassersteinDistance: 3.0963807 criticLoss: -3.0963807 generatorLoss: 1.3079216
// Epoch: [5/5] iteration: 40 wassersteinDistance: 3.2774065 criticLoss: -3.2774065 generatorLoss: 2.0451827
// Epoch: [5/5] iteration: 50 wassersteinDistance: 2.560586 criticLoss: -2.560586 generatorLoss: 1.3728871
// Epoch: [5/5] iteration: 60 wassersteinDistance: 3.6788056 criticLoss: -3.6788056 generatorLoss: 2.3687027
// Epoch: [5/5] iteration: 70 wassersteinDistance: 3.5619807 criticLoss: -3.5619807 generatorLoss: 2.0897367
// Epoch: [5/5] iteration: 80 wassersteinDistance: 3.8685439 criticLoss: -3.8685439 generatorLoss: 2.6517172
// Epoch: [5/5] iteration: 90 wassersteinDistance: 2.9292917 criticLoss: -2.9292917 generatorLoss: 1.38146
// Epoch: [5/5] iteration: 100 wassersteinDistance: 3.7015233 criticLoss: -3.7015233 generatorLoss: 2.4809034
// Epoch: [5/5] iteration: 110 wassersteinDistance: 2.8114462 criticLoss: -2.8114462 generatorLoss: 1.4761921
// Epoch: [5/5] iteration: 120 wassersteinDistance: 3.4080617 criticLoss: -3.4080617 generatorLoss: 2.0847845
// Epoch: [5/5] iteration: 130 wassersteinDistance: 3.1348898 criticLoss: -3.1348898 generatorLoss: 1.4199717
// Epoch: [5/5] iteration: 140 wassersteinDistance: 3.2089338 criticLoss: -3.2089338 generatorLoss: 1.597075
// Epoch: [5/5] iteration: 150 wassersteinDistance: 3.1277864 criticLoss: -3.1277864 generatorLoss: 1.4189932
// Epoch: [5/5] iteration: 160 wassersteinDistance: 3.5235841 criticLoss: -3.5235841 generatorLoss: 1.9755117
// Epoch: [5/5] iteration: 170 wassersteinDistance: 3.1936493 criticLoss: -3.1936493 generatorLoss: 1.7231474
// Epoch: [5/5] iteration: 180 wassersteinDistance: 3.2535853 criticLoss: -3.2535853 generatorLoss: 1.6739359
// Epoch: [5/5] iteration: 190 wassersteinDistance: 3.411067 criticLoss: -3.411067 generatorLoss: 1.7432655
// Epoch: [5/5] iteration: 200 wassersteinDistance: 3.5910132 criticLoss: -3.5910132 generatorLoss: 1.8370898
// Epoch: [5/5] iteration: 210 wassersteinDistance: 3.7033558 criticLoss: -3.7033558 generatorLoss: 1.8113592
// Epoch: [5/5] iteration: 220 wassersteinDistance: 3.1805937 criticLoss: -3.1805937 generatorLoss: 1.7419881
// Epoch: [5/5] iteration: 230 wassersteinDistance: 4.1162834 criticLoss: -4.1162834 generatorLoss: 2.3283658
// Epoch: [5/5] iteration: 240 wassersteinDistance: 4.202288 criticLoss: -4.202288 generatorLoss: 2.588079
// Epoch: [5/5] iteration: 250 wassersteinDistance: 4.725032 criticLoss: -4.725032 generatorLoss: 2.7841792
// Epoch: [5/5] iteration: 260 wassersteinDistance: 4.67894 criticLoss: -4.67894 generatorLoss: 2.7670856
// Epoch: [5/5] iteration: 270 wassersteinDistance: 3.4889393 criticLoss: -3.4889393 generatorLoss: 1.8494804
// Epoch: [5/5] iteration: 280 wassersteinDistance: 3.7440681 criticLoss: -3.7440681 generatorLoss: 2.0918753
// Epoch: [5/5] iteration: 290 wassersteinDistance: 3.210834 criticLoss: -3.210834 generatorLoss: 1.8109128
// Epoch: [5/5] iteration: 300 wassersteinDistance: 3.1029327 criticLoss: -3.1029327 generatorLoss: 1.2550769
// Epoch: [5/5] iteration: 310 wassersteinDistance: 3.392771 criticLoss: -3.392771 generatorLoss: 1.9588648
// Epoch: [5/5] iteration: 320 wassersteinDistance: 3.8672001 criticLoss: -3.8672001 generatorLoss: 2.2683947
// Epoch: [5/5] iteration: 330 wassersteinDistance: 3.9705043 criticLoss: -3.9705043 generatorLoss: 2.3591805
// Epoch: [5/5] iteration: 340 wassersteinDistance: 4.2191296 criticLoss: -4.2191296 generatorLoss: 2.0804253
// Epoch: [5/5] iteration: 350 wassersteinDistance: 3.5319705 criticLoss: -3.5319705 generatorLoss: 1.8608664
// Epoch: [5/5] iteration: 360 wassersteinDistance: 4.7240644 criticLoss: -4.7240644 generatorLoss: 2.8888216
// Epoch: [5/5] iteration: 370 wassersteinDistance: 3.7257504 criticLoss: -3.7257504 generatorLoss: 2.279388
// Epoch: [5/5] iteration: 380 wassersteinDistance: 4.031807 criticLoss: -4.031807 generatorLoss: 2.5687299
// Epoch: [5/5] iteration: 390 wassersteinDistance: 4.280424 criticLoss: -4.280424 generatorLoss: 2.8808165
// Epoch: [5/5] iteration: 400 wassersteinDistance: 3.7594135 criticLoss: -3.7594135 generatorLoss: 2.397191
// Epoch: [5/5] iteration: 410 wassersteinDistance: 3.181882 criticLoss: -3.181882 generatorLoss: 1.5532663
// Epoch: [5/5] iteration: 420 wassersteinDistance: 3.1819863 criticLoss: -3.1819863 generatorLoss: 1.8072371
// Epoch: [5/5] iteration: 430 wassersteinDistance: 3.5153944 criticLoss: -3.5153944 generatorLoss: 1.7955905
// Epoch: [5/5] iteration: 440 wassersteinDistance: 3.3343346 criticLoss: -3.3343346 generatorLoss: 1.2284285
// Epoch: [5/5] iteration: 450 wassersteinDistance: 3.3104033 criticLoss: -3.3104033 generatorLoss: 1.1894667
// Epoch: [5/5] iteration: 460 wassersteinDistance: 4.331862 criticLoss: -4.331862 generatorLoss: 2.3580313
// Epoch: [5/5] iteration: 470 wassersteinDistance: 3.5275383 criticLoss: -3.5275383 generatorLoss: 1.78528
// Epoch: [5/5] iteration: 480 wassersteinDistance: 4.1898994 criticLoss: -4.1898994 generatorLoss: 2.5299969
// Epoch: [5/5] iteration: 490 wassersteinDistance: 4.8038807 criticLoss: -4.8038807 generatorLoss: 2.6289742
// Epoch: [5/5] iteration: 500 wassersteinDistance: 3.518497 criticLoss: -3.518497 generatorLoss: 1.6380858
// Epoch: [5/5] iteration: 510 wassersteinDistance: 3.962157 criticLoss: -3.962157 generatorLoss: 1.8345971
// Epoch: [5/5] iteration: 520 wassersteinDistance: 4.52238 criticLoss: -4.52238 generatorLoss: 2.360746
// Epoch: [5/5] iteration: 530 wassersteinDistance: 3.7065277 criticLoss: -3.7065277 generatorLoss: 1.6230524
// Epoch: [5/5] iteration: 540 wassersteinDistance: 4.3263073 criticLoss: -4.3263073 generatorLoss: 2.4612575
// Epoch: [5/5] iteration: 550 wassersteinDistance: 4.4883747 criticLoss: -4.4883747 generatorLoss: 2.4947345
// Epoch: [5/5] iteration: 560 wassersteinDistance: 4.013521 criticLoss: -4.013521 generatorLoss: 1.8321916
// Epoch: [5/5] iteration: 570 wassersteinDistance: 3.9581118 criticLoss: -3.9581118 generatorLoss: 2.0326529
// Epoch: [5/5] iteration: 580 wassersteinDistance: 3.772785 criticLoss: -3.772785 generatorLoss: 1.7319065
// Epoch: [5/5] iteration: 590 wassersteinDistance: 3.8876472 criticLoss: -3.8876472 generatorLoss: 1.6912405
// Epoch: [5/5] iteration: 600 wassersteinDistance: 4.4140286 criticLoss: -4.4140286 generatorLoss: 2.150443
// Epoch: [5/5] iteration: 610 wassersteinDistance: 3.7371624 criticLoss: -3.7371624 generatorLoss: 1.1329083
// Epoch: [5/5] iteration: 620 wassersteinDistance: 4.193464 criticLoss: -4.193464 generatorLoss: 2.310441
// Epoch: [5/5] iteration: 630 wassersteinDistance: 4.1939616 criticLoss: -4.1939616 generatorLoss: 2.319785
// Epoch: [5/5] iteration: 640 wassersteinDistance: 3.7919142 criticLoss: -3.7919142 generatorLoss: 1.5450909
// Epoch: [5/5] iteration: 650 wassersteinDistance: 3.9383469 criticLoss: -3.9383469 generatorLoss: 1.4600401
// Epoch: [5/5] iteration: 660 wassersteinDistance: 3.822085 criticLoss: -3.822085 generatorLoss: 1.6889336
// Epoch: [5/5] iteration: 670 wassersteinDistance: 3.9100351 criticLoss: -3.9100351 generatorLoss: 1.7267604
// Epoch: [5/5] iteration: 680 wassersteinDistance: 4.8284135 criticLoss: -4.8284135 generatorLoss: 2.2746081
// Epoch: [5/5] iteration: 690 wassersteinDistance: 4.6163235 criticLoss: -4.6163235 generatorLoss: 2.5151062
// Epoch: [5/5] iteration: 700 wassersteinDistance: 5.264484 criticLoss: -5.264484 generatorLoss: 3.1963289
// Epoch: [5/5] iteration: 710 wassersteinDistance: 5.5585756 criticLoss: -5.5585756 generatorLoss: 3.37327
// Epoch: [5/5] iteration: 720 wassersteinDistance: 5.782913 criticLoss: -5.782913 generatorLoss: 3.3904943
// Epoch: [5/5] iteration: 730 wassersteinDistance: 5.6389537 criticLoss: -5.6389537 generatorLoss: 3.3832722
// Epoch: [5/5] iteration: 740 wassersteinDistance: 5.7585087 criticLoss: -5.7585087 generatorLoss: 3.3486483
// Epoch: [5/5] iteration: 750 wassersteinDistance: 5.537674 criticLoss: -5.537674 generatorLoss: 3.2585006
// Epoch: [5/5] iteration: 760 wassersteinDistance: 5.565154 criticLoss: -5.565154 generatorLoss: 3.1944027
// Epoch: [5/5] iteration: 770 wassersteinDistance: 5.835596 criticLoss: -5.835596 generatorLoss: 3.0957546
// Epoch: [5/5] iteration: 780 wassersteinDistance: 6.069663 criticLoss: -6.069663 generatorLoss: 3.2636247
// Shapes not compatible: [16, 32, 32, 3] != [64, 1]. Skipping
// Took: 255.1475899219513 s
// Finished. 🛬
